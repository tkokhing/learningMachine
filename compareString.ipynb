# %%
from asyncio.windows_events import NULL


def compareString(tempStringList1, tempStringList2):

    tempStringList1_Length = len(tempStringList1)   

    tempStringList2_Length = len(tempStringList2) 

    tempNumber = len(tempStringList2) 

    print(tempStringList1_Length, tempStringList2_Length)  
    # 39 and 55

    m = 0
    d = 1

    while (tempStringList1_Length > 0):
        # print(m)
        n = 0
        tempStringList2_Length = tempNumber
        while (tempStringList2_Length > 0):
            
            # if exact match
            if (tempStringList1[m] == tempStringList2[n]):
                print('m ->',m, 'n ->', n)
                print('EXACT ->',tempStringList1[m])
                # set label for exact match

            # else if partial match 
            else:
                if (len(tempStringList1[m]) > len(tempStringList2[n])):
                    shorterLength = len(tempStringList2[n])
                    shorterSentence = tempStringList2[n]
                    longerLength = len(tempStringList1[m])
                    longerSentence = tempStringList1[m]
                else: 
                    shorterLength = len(tempStringList1[m])
                    shorterSentence = tempStringList1[m]
                    longerLength = len(tempStringList2[n])
                    longerSentence = tempStringList2[n]

                # when exact AND shorter sentence inside longer sentence 
                if (shorterSentence in longerSentence):
                    # print(d)
                    print('m ->',m, 'n ->', n)
                    print('SHORTER ->', shorterSentence)
                    print('LONGER ->',longerSentence) 
                    d += 1 
                # when not exact AND shorter sentence inside longer sentence
                # the apple is red colour VS this delicious apple is sparkling red colour 
                else: 
                    slider = 0
                    print('m ->',m, 'n ->', n)
                    while(longerLength - shorterLength + 1 != slider):
                        for k in range (shorterLength):
                            if shorterSentence[k] == longerSentence[k+slider]:
                                print(shorterSentence[k],end='')
                            else:
                                print('^',end='')
                        print('\n')
                        slider += 1
                            # print(k)
                        # print('not exact AND shorter sentence inside longer sentence')


                    # break                    
                # print('No match m and n', m , n)

                # set label for partial match


            n += 1
            tempStringList2_Length -= 1

        m += 1
        tempStringList1_Length -= 1


def main():

    # stringList1 = ['is not coming to the ', 'one two three four five ', 'two three four five six ', 'three four five six seven ', 'four five six seven eight ', 'five six seven eight nine ', 'six seven eight nine ten ', 'seven eight nine ten eleven ', 'eight nine ten eleven twelve ', 'nine ten eleven twelve thirteen ', 'ten eleven twelve thirteen fourteen ', 'eleven twelve thirteen fourteen fifteen ', 'twelve thirteen fourteen fifteen sixteen ', 'thirteen fourteen fifteen sixteen seventeen ', 'fourteen fifteen sixteen seventeen eighteen ', 'fifteen sixteen seventeen eighteen nineteen ', 'sixteen seventeen eighteen nineteen twenty ', 'seventeen eighteen nineteen twenty twenty-one ', 'eighteen nineteen twenty twenty-one twenty-two ', 'nineteen twenty twenty-one twenty-two one ', 'twenty twenty-one twenty-two one two ', 'twenty-one twenty-two one two three ', 'twenty-two one two three four ', 'one two three four 5 ', 'two three four 5 six ', 'three four 5 six seven ', 'four 5 six seven eight ', '5 six seven eight nine ', 'six seven eight nine 10 ', 'seven eight nine 10 eleven', 'eight nine 10 eleven twelve ', 'nine 10 eleven twelve thirteen ', '10 eleven twelve thirteen fourteen ', 'eleven twelve thirteen fourteen 15 ', 'twelve thirteen fourteen 15 sixteen ', 'thirteen fourteen 15 sixteen seventeen ', 'fourteen 15 sixteen seventeen eighteen ', '15 sixteen seventeen eighteen nineteen ', 'sixteen seventeen eighteen ninete
    # stringList2 = ['seven eight nine 10 eleven ', 'The moseven eight nine 10 elevenuse is not coming ', 'seven eight nine 10 eleven ', 'mouse is not coming to ', 'is not coming to the ', 'inside m found in n ', 'not coming to the town ', 'coming to the town one ', 'to the town one two ', 'the town one two three ', 'town one two three so ', 'one two three so there ', 'two three so there is ', 'three so there is eleven ', 'so there is eleven of ', 'there is five six seven ', 'is eleven of the elements ', 'eleven of the elements twelve ', 'of the elements twelve thirteen ', 'the elements twelve thirteen fourteen ', 'elements twelve thirteen fourteen is ', 'twelve thirteen fourteen is to ', 'five six seven ', 'fourteen is to be fifteen ', 'is to be fifteen sixteen ', 'inside m found in n ', 'to be fifteen sixteen seventeen ', 'be fifteen sixteen seventeen eighteen ', 'fifteen sixteen seventeen eighteen coming ', 'sixteen seventeen eighteen coming nineteen ', 'seventeen eighteen coming nineteen twenty ', 'eighteen coming nineteen twenty twenty-one ', 'coming nineteen twenty twenty-one twenty-two ', 'nineteen twenty twenty-one twenty-two one ', 'twenty twenty-one twenty-two one two ', 'twenty-one twenty-two one two here ', 'twenty-two one two here three ', 'one two here three four ', 'two here three four 5 ', 'here three four 5 six ', 'inside n embedded in m', 'four 5 six seven eight ', '5 six seven eight nine ', 'six seven eight nine 10 ', 'inside m found in n ', 'eight nine 10 eleven twelve ', 'nine 10 eleven twelve thirteen ', '10 eleven twelve thirteen fourteen ', 'eleven twelve thirteen fourteen 15 ', 'twelve thirteen fourteen 15 this ', 'twelve thirteen fourteen', 'thirteen fourteen 15 this testing ', 'fourteen 15 this testing ends ', '15 this testing ends here ', 'this testing ends here sixteen ', 'testing ends inside m found in n here sixteen seventeen ', 'ends here sixteen seventeen eighteen ', 'here sixteen sinside m found in nhteen nineteen ', 'twelve thirteen fourteen', 'sixteen seventeen eighteen nineteen 20 ', 'seventeen eighteen nineteen 20 twenty-one ', 'inside m found in n ', 'five six seven ']

    # stringList1 = ['is not coming to the ', 'one two three four five ', 'two three four five six ', 'three four five six seven ', 'four five six seven eight ', 'five six seven eight nine ', 'six seven eight nine ten ', 'seven eight nine ten eleven ', 'eight inside n embedded in m nine ten eleven twelve ', 'nine ten eleven twelve thirteen ', 'ten eleven twelve thirteen fourteen ', 'eleven twelve thirteen fourteen fifteen ', 'twelve thirteen fourteen fifteen sixteen ', 'thirteen fourteen fifteen sixteen seventeen ', 'fourteen fifteen sixteen seventeen eighteen ', 'fifteen sixteen seventeen eighteen nineteen ', 'inside me embedded in n', 'seventeen eighteen nineteen twenty twenty-one ', 'eighteen nineteen twenty twenty-one twenty-two ', 'nineteen tweinside n embedded in mnty twenty-one twenty-two one ', 'twenty twenty-one twenty-two one two ', 'twenty-one twenty-two one two three ', 'twenty-two one two three four ', 'one two three four 5 ', 'two three four 5 six ', 'three four 5 six seven ', 'four 5 six seven eight ', '5 six seven eight nine ', 'six seven eight nine 10 ', 'seven eiginside n embedded in mht nine 10 eleven', 'eight nine 10 eleven twelve ', 'nine 10 eleven twelve thirteen ', '10 eleven twelve thirteen fourteen ', 'eleven twelve thirteen fourteen 15 ', 'twelve thirteen fourteen 15 sixteen ', 'thirteen fourteen 15 sixteen seventeen ', 'fourteen 15 sixteen seventeen eighteen ', '15 sixteen seventeen eighteen nineteen ', 'sixteen seventeen eighteen nineteen 20 ', 'seventeen eighteen nineteen 20 twenty-one ']

    # stringList2 = ['seven eight nine 10 eleven ', 'The moseven eight nine 10 elevenuse is not coming ', 'seven eight nine 10 eleven ', 'mouse is not coming to ', 'is not coming to the ', 'inside m found in n ', 'not coming to the town ', 'coming to the town one ', 'to the town one two ', 'the town one two three ', 'town one two three so ', 'one two three so there ', 'two three so there is ', 'three so there is eleven ', 'so thinside me embedded in nere is eleven of ', 'there is five six seven ', 'is eleven of the elements ', 'eleven of the elements tw
ixteen seventeen eighteen nineteen ', 'sixteen seventeen eighteen nineteen twenty ', 'seventeen eighteen nineteen twenty twenty-one ', 'eighteen nineteen twenty twenty-one twenty-two ', 'nineteen twenty twenty-one twenty-two 1 ', 'twenty twenty-one twenty-two 1 two ', 'twenty-one twenty-two 1 two three ', 'twenty-two 1 two three four ', '1 two three four 5 ', 'two three four 5 six ', 'three four 5 six seven ', 'four 5 six seven eight ', '5 six seven eight nine ', 'six seven eight nine 10 ', 'seven eight nine 10 eleven ', 'eight nine 10 eleven twelve ', 'nine 10 eleven twelve thirteen ', '10 eleven twelve thirteen fourteen ', 'eleven twelve thirteen fourteen 15 ', 'twelve thirteen fourteen 15 sixteen ', 'thirteen fourteen 15 sixteen seventeen ', 'fouinside m embedded in n three times rteen 15 sixteen seventeen eighteen ', '15 sixteen seventeen eighteen nineteen ', 'sixteen seventeen eighteen nineteen 20 ', 'seventeen eighteen nineteen 20 twenty-one ']

    # stringList1 = ['this testing ends here', 'coming to the town', 'the apple is red colour ']
    # stringList2 = ['one two here thrthis testing ends hereght nine 10!', 'coming to the town', 'this delicious apple is sparkling red colour ' ] # embedded




    compareString(stringList1, stringList2)



if __name__ == '__main__':
    main()
# Out:
# 40 40
# m -> 0 n -> 0
# one two th^^^^^^^^ ^^^e^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^e ^^^^^^^^e^
#
# ^^^ t^^^^^^e^^^^^^^^^^^
#
# ^^^^^^^^^^^^^ ^^^^^^^^^^
#
# o^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^e^^^^^^^^^^
#
# ^^^^^^^^^^^e^^^^^^^^i^^^
#
# ^^^^^^^ ^^^^^^^^^^ ^^^^
#
# ^n^^^^^^^^^^e^^^^^^^^^^^
#
# ^^^^^^^ ^^^e^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^ ^^^^^
#
# ^^e ^^^^^^^^e^^^^^^^^^^
#
# ^^^^^^^^^^^e^ ^^^^ ^i^^^
#
# ^^^ ^^^^^^^^^^^^^^^^^^^^
#
# ^n^^^^^^^^^^^^^^^^^^^^^^
#
# ^^e^^^^^^^^^^ ^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^ ^i^e^
#
# ^^^^^^^^^^^^^ ^^^^^^^^^
#
# ^^e^^^^ ^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^^^^^e^
#
# ^^e^^^^ ^^^^^ ^^^^^^^^e
#
# ^^^ ^^^^^^^^^^^^^^ ^^^^^
#
# ^^^^^^^ ^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^r^^^^^^
#
# ^^^ ^^^^^^^^^^^^^^^^^^^^
#
# ^n^^^^^^^^^^e^^^^^ f^^^
#
# ^^^ ^^^ t^^e^ ^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^^^^^^^^^^^^^
#
# ^^^^^^^^^^^^e^^^^^^^^^^^
#
# ^^^ t^^^^^ree four five
# ...
